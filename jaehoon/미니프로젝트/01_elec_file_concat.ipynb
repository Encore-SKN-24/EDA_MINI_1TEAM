# %%
import glob
import pandas as pd

# 폴더 내 모든 csv 파일 불러오기
file_path = "./data/elec_detail_years/*.xlsx"
file_list = glob.glob(file_path)

# 데이터프레임 합치기
df_list = [pd.read_excel(file, header=2) for file in file_list]
final_df = pd.concat(df_list, ignore_index=True)
final_df = final_df.drop_duplicates()
final_df.to_csv('elect_2015_2024.csv',encoding='CP949')

# %%
# 연도 확인
print(sorted(final_df['연도'].unique()))

# 결측치 확인
final_df.isna().sum()
# Out:
# [np.int64(2015), np.int64(2016), np.int64(2017), np.int64(2018), np.int64(2019), np.int64(2020), np.int64(2021), np.int64(2022), np.int64(2023), np.int64(2024)]
# 연도      0
# 시도      0
# 시군구     0
# 계약종별    0
# 1월      0
# 2월      0
# 3월      0
# 4월      0
# 5월      0
# 6월      0
# 7월      0
# 8월      0
# 9월      0
# 10월     0
# 11월     0
# 12월     0
# dtype: int64
