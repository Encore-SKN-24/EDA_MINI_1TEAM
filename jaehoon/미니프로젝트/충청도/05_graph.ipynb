# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

plt.rc("font", family = "Malgun Gothic")
sns.set(font="Malgun Gothic", 
rc={"axes.unicode_minus":False}, style='white')

# # 한글 폰트 설정 (Mac)
# plt.rc('font', family='AppleGothic')
# # 마이너스 기호 깨짐 방지
# plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# ### 교육용 농업용,산업용, 가로등, 심야, 일반용, 주택용

# %%
import pandas as pd
chung_general = pd.read_csv('C:/skn24/2601_mini_team/EDA_MINI_1TEAM/jaehoon/미니프로젝트/data/preprocessing/충청도 데이터/머지/일반용_elect_temp_gangwon.csv',encoding='utf-8')
chung_house = pd.read_csv('C:/skn24/2601_mini_team/EDA_MINI_1TEAM/jaehoon/미니프로젝트/data/preprocessing/충청도 데이터/머지/주택용_elect_temp_gangwon.csv',encoding='utf-8')
chung_light = pd.read_csv('C:/skn24/2601_mini_team/EDA_MINI_1TEAM/jaehoon/미니프로젝트/data/preprocessing/충청도 데이터/머지/가로등_elect_temp_gangwon.csv',encoding='utf-8')
chung_farm = pd.read_csv('C:/skn24/2601_mini_team/EDA_MINI_1TEAM/jaehoon/미니프로젝트/data/preprocessing/충청도 데이터/머지/농사용_elect_temp_gangwon.csv',encoding='utf-8')
chung_edu = pd.read_csv('C:/skn24/2601_mini_team/EDA_MINI_1TEAM/jaehoon/미니프로젝트/data/preprocessing/충청도 데이터/머지/교육용_elect_temp_gangwon.csv',encoding='utf-8')
chung_night = pd.read_csv('C:/skn24/2601_mini_team/EDA_MINI_1TEAM/jaehoon/미니프로젝트/data/preprocessing/충청도 데이터/머지/심 야_elect_temp_gangwon.csv',encoding='utf-8')
chung_industry = pd.read_csv('C:/skn24/2601_mini_team/EDA_MINI_1TEAM/jaehoon/미니프로젝트/data/preprocessing/충청도 데이터/머지/산업용_elect_temp_gangwon.csv',encoding='utf-8')
chung_total = pd.read_csv('C:/skn24/2601_mini_team/EDA_MINI_1TEAM/jaehoon/미니프로젝트/data/preprocessing/충청도 데이터/머지/합 계_elect_temp_gangwon.csv',encoding='utf-8')

chung_general = chung_general[['지점', '지점명', '일시', '평균기온(°C)',
       '평균현지기압(hPa)', '평균해면기압(hPa)', '평균수증기압(hPa)', '평균상대습도(%)',
       '월합강수량(00~24h만)(mm)', '평균풍속(m/s)', '일조율(%)', '최심적설(cm)', '평균지면온도(°C)',
       'years', 'month', '시도', '시군구', '계약종별', '전력량','HDD','CDD']]
chung_general = chung_general.rename({'전력량':'전력사용량'},axis=1)


chung_house = chung_house[['지점', '지점명', '일시', '평균기온(°C)',
       '평균현지기압(hPa)', '평균해면기압(hPa)', '평균수증기압(hPa)', '평균상대습도(%)',
       '월합강수량(00~24h만)(mm)', '평균풍속(m/s)', '일조율(%)', '최심적설(cm)', '평균지면온도(°C)',
       'years', 'month', '시도', '시군구', '계약종별', '전력량','HDD','CDD']]
chung_house = chung_house.rename({'전력량':'전력사용량'},axis=1)

chung_light = chung_light[['지점', '지점명', '일시', '평균기온(°C)',
       '평균현지기압(hPa)', '평균해면기압(hPa)', '평균수증기압(hPa)', '평균상대습도(%)',
       '월합강수량(00~24h만)(mm)', '평균풍속(m/s)', '일조율(%)', '최심적설(cm)', '평균지면온도(°C)',
       'years', 'month', '시도', '시군구', '계약종별', '전력량','HDD','CDD']]
chung_light = chung_light.rename({'전력량':'전력사용량'},axis=1)

chung_farm = chung_farm[['지점', '지점명', '일시', '평균기온(°C)',
       '평균현지기압(hPa)', '평균해면기압(hPa)', '평균수증기압(hPa)', '평균상대습도(%)',
       '월합강수량(00~24h만)(mm)', '평균풍속(m/s)', '일조율(%)', '최심적설(cm)', '평균지면온도(°C)',
       'years', 'month', '시도', '시군구', '계약종별', '전력량','HDD','CDD']]
chung_farm = chung_farm.rename({'전력량':'전력사용량'},axis=1)

chung_edu = chung_edu[['지점', '지점명', '일시', '평균기온(°C)',
       '평균현지기압(hPa)', '평균해면기압(hPa)', '평균수증기압(hPa)', '평균상대습도(%)',
       '월합강수량(00~24h만)(mm)', '평균풍속(m/s)', '일조율(%)', '최심적설(cm)', '평균지면온도(°C)',
       'years', 'month', '시도', '시군구', '계약종별', '전력량','HDD','CDD']]
chung_edu = chung_edu.rename({'전력량':'전력사용량'},axis=1)

chung_night = chung_night[['지점', '지점명', '일시', '평균기온(°C)',
       '평균현지기압(hPa)', '평균해면기압(hPa)', '평균수증기압(hPa)', '평균상대습도(%)',
       '월합강수량(00~24h만)(mm)', '평균풍속(m/s)', '일조율(%)', '최심적설(cm)', '평균지면온도(°C)',
       'years', 'month', '시도', '시군구', '계약종별', '전력량','HDD','CDD']]
chung_night = chung_night.rename({'전력량':'전력사용량'},axis=1)


chung_industry = chung_industry[['지점', '지점명', '일시', '평균기온(°C)',
       '평균현지기압(hPa)', '평균해면기압(hPa)', '평균수증기압(hPa)', '평균상대습도(%)',
       '월합강수량(00~24h만)(mm)', '평균풍속(m/s)', '일조율(%)', '최심적설(cm)', '평균지면온도(°C)',
       'years', 'month', '시도', '시군구', '계약종별', '전력량','HDD','CDD']]
chung_industry = chung_industry.rename({'전력량':'전력사용량'},axis=1)

chung_total = chung_total[['지점', '지점명', '일시', '평균기온(°C)',
       '평균현지기압(hPa)', '평균해면기압(hPa)', '평균수증기압(hPa)', '평균상대습도(%)',
       '월합강수량(00~24h만)(mm)', '평균풍속(m/s)', '일조율(%)', '최심적설(cm)', '평균지면온도(°C)',
       'years', 'month', '시도', '시군구', '계약종별', '전력량','HDD','CDD']]
chung_total = chung_total.rename({'전력량':'전력사용량'},axis=1)

# %%
chung_industry
# Out:
#        지점 지점명       일시  평균기온(°C)  평균현지기압(hPa)  평균해면기압(hPa)  평균수증기압(hPa)  \
# 0     127  충주  2015-01      -1.7       1010.3       1024.9          3.8
# 1     127  충주  2015-02       0.6       1008.0       1022.6          3.9
# 2     127  충주  2015-03       5.6       1007.2       1021.4          4.0
# 3     127  충주  2015-04      12.5       1002.5       1016.3          8.1
# 4     127  충주  2015-05      18.5        996.4       1009.8         10.6
# ...   ...  ..      ...       ...          ...          ...          ...
# 1250  239  세종  2024-08      28.1        996.9       1006.9         29.3
# 1251  239  세종  2024-09      25.2       1002.4       1012.6         24.6
# 1252  239  세종  2024-10      15.7       1009.3       1019.9         14.7
# 1253  239  세종  2024-11       9.5       1011.1       1022.1          8.8
# 1254  239  세종  2024-12       1.3       1012.7       1024.0          4.6
#
#       평균상대습도(%)  월합강수량(00~24h만)(mm)  평균풍속(m/s)  ...  최심적설(cm)  평균지면온도(°C)  \
# ...

# %%
# chung_general 
# chung_house 
# chung_light
# chung_farm 
# chung_edu 
# chung_night
# chung_industry

# %%
dfs = {
    '주택용': chung_house,
    '일반용': chung_general,
    '교육용': chung_edu,
    '산업용': chung_industry,
    '농사용': chung_farm,
    '심야': chung_night,
    '가로등': chung_light,
    '합계' : chung_total
}

all_frame = []
for name, df in dfs.items():
    temp = df.copy()
    temp['계약종별'] = name
    all_frame.append(temp)

gangwon_type = pd.concat(all_frame,ignore_index=True)
gangwon_type.groupby(['years'])['전력사용량'].mean()
sns.boxplot(data=gangwon_type, x='계약종별', y='전력사용량')
plt.title('충청도 계약종별 전력사용량',fontweight='bold', fontsize=16)
print(gangwon_type.keys())
dfs.keys()
# Out:
# Index(['지점', '지점명', '일시', '평균기온(°C)', '평균현지기압(hPa)', '평균해면기압(hPa)',
#        '평균수증기압(hPa)', '평균상대습도(%)', '월합강수량(00~24h만)(mm)', '평균풍속(m/s)', '일조율(%)',
#        '최심적설(cm)', '평균지면온도(°C)', 'years', 'month', '시도', '시군구', '계약종별',
#        '전력사용량', 'HDD', 'CDD'],
#       dtype='object')
# dict_keys(['주택용', '일반용', '교육용', '산업용', '농사용', '심야', '가로등', '합계'])

# %%
gr_year = gangwon_type.groupby(['계약종별','years'])['전력량'].mean()
gr_year
# gr_year.plot(x='계약종별', y='전력량')
# gr_year.pivot(index='계약종별', columns='years', values='전력량')
# plt.show()
# Out:
# 계약종별  years
# 가로등   2015     1.565154e+06
#       2016     1.553559e+06
#       2017     1.593253e+06
#       2018     1.585497e+06
#       2019     1.620571e+06
#                    ...
# 합계    2020     3.064900e+08
#       2021     3.324047e+08
#       2022     3.432365e+08
#       2023     3.457388e+08
#       2024     3.372886e+08
# Name: 전력량, Length: 80, dtype: float64
